# %%
#Tuples 
l1=(1,2,3)
#Similar to list in that way
#TUPLES ARE IMMUTABLE
#l1[2]=8 WILL GIVE AN ERROR
print(l1)
l2=list(l1)
print(type(l2))
l2[2]=9
print(l2)
# Out:
# (1, 2, 3)
# <class 'list'>
# [1, 2, 9]

# %%
#importing classes - OOP - classes have attributes and methods
#import modulex
#print(modulex.data1)
#modulex.funct1()

from turtle import Turtle, Screen
timmy = Turtle()
print(timmy)
timmy.shape("turtle")
timmy.color("teal")
timmy.forward(100)
my_screen = Screen()
print(my_screen.canvheight)
my_screen.exitonclick()

from prettytable import PrettyTable
pt = PrettyTable()
print(pt)
pt.add_column("City name",
["Adelaide","Brisbane","Darwin","Hobart","Sydney","Melbourne","Perth"])
pt.add_column("Area", [1295, 5905, 112, 1357, 2058, 1566, 5386])
pt.add_column("Population", [1158259, 1857594, 120900, 205556, 4336374, 3806092,
1554769])
pt.add_column("Annual Rainfall",[600.5, 1146.4, 1714.7, 619.5, 1214.8, 646.9,
869.4])
print(pt)
pt.add_rows(
    [
        ["Adelaide", 1295, 1158259, 600.5],
        ["Brisbane", 5905, 1857594, 1146.4],
    ]
)
pt.add_row(["Adelaide", 1295, 1158259, 600.5])
print(pt)
# Out:
# ...
# 300
# ++
# ||
# ++
# ++
# +-----------+------+------------+-----------------+
# | City name | Area | Population | Annual Rainfall |
# +-----------+------+------------+-----------------+
# |  Adelaide | 1295 |  1158259   |      600.5      |
# |  Brisbane | 5905 |  1857594   |      1146.4     |
# |   Darwin  | 112  |   120900   |      1714.7     |
# |   Hobart  | 1357 |   205556   |      619.5      |
# |   Sydney  | 2058 |  4336374   |      1214.8     |
# | Melbourne | 1566 |  3806092   |      646.9      |
# |   Perth   | 5386 |  1554769   |      869.4      |
# +-----------+------+------------+-----------------+
# +-----------+------+------------+-----------------+
# | City name | Area | Population | Annual Rainfall |
# +-----------+------+------------+-----------------+
# |  Adelaide | 1295 |  1158259   |      600.5      |
# |  Brisbane | 5905 |  1857594   |      1146.4     |
# |   Darwin  | 112  |   120900   |      1714.7     |
# |   Hobart  | 1357 |   205556   |      619.5      |
# ...

# %%
from turtle import Turtle, Screen
import random

timmy = Turtle()
timmy.speed=0
timmy.shape("turtle")
timmy.color("teal")
timmy.pencolor("maroon")
for i in range(0, 4):
    timmy.forward(100)
    timmy.right(90)
timmy.left(90)
for i in range(0, 5):
    # penup pendown also can be used here
    timmy.forward(10)
    timmy.pencolor("white")
    timmy.forward(10)
    timmy.pencolor("maroon")

    timmy.forward(10)
    timmy.penup()
    timmy.forward(10)
    timmy.pendown()

def shape_draw(num):
    for i in range(0, num):
        timmy.forward(50)
        timmy.right(360 / num)
        
timmy.pencolor("darkblue")
for i in range(3, 12):
    shape_draw(i)

timmy.pensize(10)
timmy.backward(100)

while 1:
    x = random.random()
    y = random.random()
    z = random.random()
    tup=(x,y,z)
    timmy.pencolor(tup)
    dist = random.randint(1,10)
    times = random.randint(0,3)
    timmy.setheading(90*times)
    timmy.forward(dist*10)

# %%
import random
from turtle import Turtle as t, Screen as s
timmy = t()
timmy.speed(0)
timmy.pensize(3)
rad=150
ah=5
for i in range(0,int(360/ah)):
    x = random.random()
    y = random.random()
    z = random.random()
    tup=(x,y,z)
    timmy.pencolor(tup)
    timmy.circle(rad)
    timmy.setheading(timmy.heading()+ah)

my_screen = s()
my_screen.exitonclick()

# %%
import colorgram
import random
colors = colorgram.extract('pics.jpeg', 48)
color_lib = []
print(colors)

for color in colors:
    rgb = color.rgb
    r=rgb[0]
    g=rgb[1]
    b=rgb[2]
    tup=(r,g,b)
    color_lib.append(tup)
print(color_lib)
print(len(color_lib))
color_list = [(236, 224, 80), (197, 7, 71), (195, 164, 13), (201, 75, 15), (231, 54, 132), (110, 179, 216), (217, 163, 101), (27, 105, 168), (35, 186, 109), (19, 29, 168), (13, 23, 66), (212, 135, 177), (233, 223, 7), (199, 33, 132), (13, 183, 212), (230, 166, 199), (126, 189, 162), (8, 49, 28), (40, 132, 77), (128, 219, 232), (58, 12, 25), (67, 22, 7), (114, 90, 210), (146, 216, 199), (179, 17, 8), (233, 66, 34), (11, 97, 52), (169, 181, 232), (241, 169, 155), (252, 7, 40), (10, 84, 100), (63, 98, 8), (14, 51, 250), (250, 11, 8)]

from turtle import Turtle as t, colormode as c, Screen as s

timmy = t()
c(255)
timmy.penup()
timmy.speed(0)
timmy.hideturtle()
for i in range(1,101):
    timmy.dot(15,random.choice(color_list))
    timmy.forward(25)
    if i%10==0 and i!=100:
        timmy.left(180)
        timmy.forward(25*10)
        timmy.right(90)
        timmy.forward(25)
        timmy.right(90)
my_screen = s()
my_screen.exitonclick()
# Out:
# [<colorgram.py Color: Rgb(r=249, g=248, b=244), 49.144179104477615%>, <colorgram.py Color: Rgb(r=250, g=245, b=248), 20.228358208955225%>, <colorgram.py Color: Rgb(r=243, g=250, b=246), 11.95134328358209%>, <colorgram.py Color: Rgb(r=236, g=244, b=250), 6.385074626865672%>, <colorgram.py Color: Rgb(r=236, g=224, b=80), 1.2740298507462686%>, <colorgram.py Color: Rgb(r=197, g=7, b=71), 0.7976119402985075%>, <colorgram.py Color: Rgb(r=195, g=164, b=13), 0.7205970149253732%>, <colorgram.py Color: Rgb(r=201, g=75, b=15), 0.7149253731343284%>, <colorgram.py Color: Rgb(r=231, g=54, b=132), 0.704179104477612%>, <colorgram.py Color: Rgb(r=110, g=179, b=216), 0.6949253731343283%>, <colorgram.py Color: Rgb(r=217, g=163, b=101), 0.6638805970149254%>, <colorgram.py Color: Rgb(r=27, g=105, b=168), 0.5788059701492537%>, <colorgram.py Color: Rgb(r=35, g=186, b=109), 0.5385074626865671%>, <colorgram.py Color: Rgb(r=19, g=29, b=168), 0.5313432835820896%>, <colorgram.py Color: Rgb(r=13, g=23, b=66), 0.
# ...

# %%
from turtle import Turtle, Screen
import random

def move_forward():
    timmy.forward(10)
def move_back():
    timmy.back(10)

def move_right():
    timmy.left(45)

def move_left():
    timmy.right(45)

def clear():
    timmy.clear()

screen=Screen()
timmy = Turtle()
timmy.speed(0)
timmy.setheading(90)
screen.listen()
screen.onkey(fun=move_forward, key='w')
screen.onkey(fun=move_back, key='s')
screen.onkey(fun=move_right, key='a')
screen.onkey(fun=move_left, key='d')
screen.onkey(fun=clear,key='c')
screen.exitonclick()

# %%
from turtle import Turtle, Screen
import random

is_race_on = False
screen = Screen()
screen.setup(width=500, height=400)
user_bet = screen.textinput(title="Make your bet", prompt="Which turtle will win the race? Enter a color: ")
colors = ["red", "orange", "yellow", "green", "blue", "purple"]
y_positions = [-70, -40, -10, 20, 50, 80]
all_turtles = []

for turtle_index in range(0, 6):
    new_turtle = Turtle(shape="turtle")
    new_turtle.penup()
    new_turtle.color(colors[turtle_index])
    new_turtle.goto(x=-230, y=y_positions[turtle_index])
    all_turtles.append(new_turtle)

if user_bet:
    is_race_on = True

while is_race_on:
    for turtle in all_turtles:
        if turtle.xcor() > 230:
            is_race_on = False
            winning_color = turtle.pencolor()
            if winning_color == user_bet:
                print(f"You've won! The {winning_color} turtle is the winner!")
            else:
                print(f"You've lost! The {winning_color} turtle is the winner!")

        rand_distance = random.randint(0, 10)
        turtle.forward(rand_distance)

screen.exitonclick()
# Out:
# You've lost! The yellow turtle is the winner!

# %%
#Use pass to pass the indent without any content
#Classes are blueprints. They have Attributes and Methods
#Constructor function used to initialize variables to their starting values. 
#used by init function
#PascalCase for class names
#camelCase
#snake_case for normal variables

#Inheritance - Acquiring methods and attributes from an existing class

class CarFather:
    def __init__(self):
        pass

class CarSon(CarFather):
    def __init__(self):
        super().__init__()

#Super init initializes everything that the super class can do        
#The call to super() in the initialiser is recommended, but not strictly required.

class Animal:
    def __init__(self):
        self.num_eyes = 2

    def breathe(self):
        print("Inhale, exhale.")

class Fish(Animal):
    def __init__(self):
        super().__init__()

    def breathe(self):
        super().breathe()
        print("doing this underwater.\n\n")

    def swim(self):
        print("moving in water.")

nemo = Fish()
nemo.breathe()

#The above breathe function in fish is inherited and also there is adding more information to it

class Car:
    pass

car1 = Car()
car1.idd ="001"
car1.name="Rochan"
print(car1.idd+" "+car1.name)



class Bike:
    def __init__(self,seats=2,wheels=2):
        #Number of seats are 4 by default
        print("NEW USER")
        self.seats=seats
        self.wheels=wheels
        self.windows=0
    
    def enter_race_mode(self): 
        #METHOD
        self.seats=1
 
bike1 = Bike(2)
bike2 = Bike(6,10)
print(str(bike1.seats)+" "+str(bike1.wheels))
print(str(bike2.seats)+" "+str(bike2.wheels))
bike2.enter_race_mode()
print(str(bike2.seats)+" "+str(bike2.wheels))



class User:
        def __init__(self):
            self.following=0
            self.followers=0
        def follow(self,user):
            user.followers+=1
            self.following+=1   
user1=User()
user2=User()
print(f"U1 {user1.following} {user1.followers}\nU2 {user2.following} {user2.followers}") 
user1.follow(user2)
user2.follow(user1)
print(f"U1 {user1.following} {user1.followers}\nU2 {user2.following} {user2.followers}")
# Out:
# Inhale, exhale.
# doing this underwater.
# 001 Rochan
# NEW USER
# NEW USER
# 2 2
# 6 10
# 1 10
# U1 0 0
# U2 0 0
# U1 1 1
# U2 1 1

# %%
from data import question_data, QuestionModel
#https://opentdb.com/api_config.php
import random
q1=QuestionModel('HEY',"True")
q1.text,q1.answer
qb=[]

gameon=1
score=0
def scorey():
    global score
    score+=1

for i in range(len(question_data)):
    #qt=question_data[i]['text']
    #qa=question_data[i]['answer']
    #q1=QuestionModel(qt,qa)
    q1=QuestionModel(question_data[i]['text'],question_data[i]['answer'])
    qb.append(q1)
print(qb)
print("\n\n\n")

#Can make the quiz game with this
while gameon==1:
    if len(qb)>0:
        i=random.randint(0,len(qb)-1)
        print(qb[i].text)
        ans=input("Enter True or False\n").title()
        if ans==qb[i].answer:
            print("CORRECT")
            del qb[i]
            scorey()
            print(score)
            print("\n\n\n")
        else:
            print("The answer is "+qb[i].answer+"\nINCORRECT")
            gameon=0
            print("\n\nGame over. Score is "+str(score))
    else:
        print("YOU WIN!!!")
        gameon=0
# Out:
# [<data.QuestionModel object at 0x000001D733B6CBB0>, <data.QuestionModel object at 0x000001D733B6CB80>, <data.QuestionModel object at 0x000001D733B6CCA0>, <data.QuestionModel object at 0x000001D733B6CBE0>, <data.QuestionModel object at 0x000001D733B6CD00>, <data.QuestionModel object at 0x000001D733B6CE20>, <data.QuestionModel object at 0x000001D733B6CE50>, <data.QuestionModel object at 0x000001D733B6CF40>, <data.QuestionModel object at 0x000001D733B6CFA0>, <data.QuestionModel object at 0x000001D733B6CC70>, <data.QuestionModel object at 0x000001D733B6CEB0>, <data.QuestionModel object at 0x000001D733ACEA60>]
#
#
#
#
# Google was originally called 'Backrub'.
# Enter True or False
# false
# The answer is True
# INCORRECT
#
#
# Game over. Score is 0

# %% [markdown]
# # SNAKE GAME

# %%
from turtle import Turtle, Screen
import time
from snakesy import Snakey
from snakesfood import foods
from snakescore import scoreboard

STARTING_POSITIONS = [(0, 0), (-20, 0), (-40, 0)]

s = Screen()
s.setup(600, 600)
s.title("Snake Game")
s.bgcolor("black")
x = 0
y = 0
s.tracer(0)
snake = Snakey()
food = foods()
sc = scoreboard()
s.update()
game_on = 1
while game_on == 1:
    s.update()
    time.sleep(0.1)
    snake.move_snake()
    if snake.segments[0].distance(food) < 15:
        food.refresh()
        snake.add_seg()
        sc.scored()
    if snake.segments[0].xcor()>280 or snake.segments[0].xcor()<-280 or snake.segments[0].ycor()>290 or snake.segments[0].ycor()<-290:
        game_on=0
        sc.game_over()
    for i in snake.segments[1:]:
        if snake.segments[0].distance(i) < 10:
            game_on = 0
            sc.game_over()
    s.listen()
    s.onkey(fun=snake.move_up, key='Up')
    s.onkey(fun=snake.move_down, key='Down')
    s.onkey(fun=snake.move_left, key='Left')
    s.onkey(fun=snake.move_right, key='Right')

s.exitonclick()

# %% [markdown]
# # Ping Pong

# %%
from turtle import Turtle, Screen
from pingpongstick1 import P1Stick
from pingpongscore import scoreboard
from pingpongball import balls
import random
import time

s = Screen()
s.setup(800, 600)
s.bgcolor("black")
s.title("Ping Pong")
s.tracer(0)
p1 = P1Stick(350, 0)
p2 = P1Stick(-350, 0)
ball = balls(0, 0)
sb = scoreboard()
s.update()
sleeptime = 0.01
counter = 0
game_on = 1
score1 = 0
score2 = 0
while game_on == 1:
    s.update()
    time.sleep(sleeptime)
    ball.move()
    s.listen()
    if ball.inst[0].ycor() > 280 or ball.inst[0].ycor() < -280:
        ball.bounce()
    if (ball.inst[0].distance(p1.inst[0]) < 50 and ball.inst[0].xcor() > 340 or ball.inst[0].distance(p2.inst[0]) < 50
            and ball.inst[0].xcor() < -340):
        counter += 1
        ball.change_direction()
        print(sleeptime)
        if counter % 2 == 0:
            sleeptime *= 0.9
    if ball.inst[0].xcor() > 350:
        score1 += 1
        sb.score(score1, score2)
        ball.restart()
        time.sleep(0.5)
        sleeptime=0.01
    if ball.inst[0].xcor() < -350:
        score2 += 1
        sb.score(score1, score2)
        ball.restart()
        time.sleep(0.5)
        sleeptime = 0.01
    if score1>5:
        game_on = 0
        sb.game_over(1)
    if score2>5:
        game_on = 0
        sb.game_over(2)
    s.onkeypress(fun=p1.move_up, key='Up')
    s.onkeypress(fun=p1.move_down, key='Down')
    s.onkeypress(fun=p2.move_up, key='w')
    s.onkeypress(fun=p2.move_down, key='s')

s.exitonclick()
# Out:
# 0.01
# 0.01
# 0.009000000000000001
# 0.009000000000000001
# 0.008100000000000001
# 0.008100000000000001
# 0.007290000000000001
# 0.007290000000000001
# 0.006561000000000002
# 0.006561000000000002
# 0.005904900000000002
# 0.005904900000000002
# 0.005314410000000002
# 0.005314410000000002
# 0.004782969000000002
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-1-5eaaa2eb0a34> in <module>
#      24     s.update()
#      25     time.sleep(sleeptime)
# ---> 26     ball.move()
#      27     s.listen()
#      28     if ball.inst[0].ycor() > 280 or ball.inst[0].ycor() < -280:
#
# ~\UNTITLED PYTHON PROGRAMS\DAY 16 - 23\pingpongball.py in move(self)
#      23         newx = self.inst[0].xcor()+self.xmove
#      24         newy = self.inst[0].ycor()+self.ymove
# ---> 25         self.inst[0].goto(newx, newy)
#      26
#      27     def restart(self):
#
# ...

# %% [markdown]
# # Cross

# %%
from turtle import Turtle, Screen

#scoreboard
#obstacles
#mainturtle

s = Screen()
s.setup(1000,800)
s.bgcolor("black")
s.title("Cross")



s.exitonclick()

# %%
#tk - tkinter -> tkinterface for making python a gui - graphical user interface
