# %%
print("Hey there")
# Out:
# Hey there

# %%
# Out:
# ['day,temp,condition\n', 'Monday,12,Sunny\n', 'Tuesday,14,Rain\n', 'Wednesday,15,Rain\n', 'Thursday,14,Cloudy\n', 'Friday,21,Sunny\n', 'Saturday,22,Sunny\n', 'Sunday,24,Sunny']

# %%
import csv
with open("weather_data.csv") as datafile:
    data = csv.reader(datafile)
    print(data)
    temperatures = []
    for row in data:
        print(row)
        if row[1] != "temp":
            temperatures.append(int(row[1]))
print("\n")
print(temperatures)
# Out:
# ...
# ['day', 'temp', 'condition']
# ['Monday', '12', 'Sunny']
# ['Tuesday', '14', 'Rain']
# ['Wednesday', '15', 'Rain']
# ['Thursday', '14', 'Cloudy']
# ['Friday', '21', 'Sunny']
# ['Saturday', '22', 'Sunny']
# ['Sunday', '24', 'Sunny']
#
#
# [12, 14, 15, 14, 21, 22, 24]

# %%
import pandas as pd
data = pd.read_csv("weather_data.csv")
print(data)
print(type(data))
print('\n')
print(data['temp'])
print(type(data['temp']))
# Out:
#          day  temp condition
# 0     Monday    12     Sunny
# 1    Tuesday    14      Rain
# 2  Wednesday    15      Rain
# 3   Thursday    14    Cloudy
# 4     Friday    21     Sunny
# 5   Saturday    22     Sunny
# 6     Sunday    24     Sunny
# <class 'pandas.core.frame.DataFrame'>
#
#
# 0    12
# 1    14
# 2    15
# 3    14
# 4    21
# 5    22
# 6    24
# Name: temp, dtype: int64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Primary Data Structures of Pandas<br>
# Series for 1D<br>
# DataFrames for 2D<br>
#
# Name of the column is taken as the first row content by default
#
# Pandas has a lot of functions to convert data to different formats and files like csv, html, json.
# Some functions for computations, length, mean, and all that.
# Check documentation

# %%
dict_data = data.to_dict()

print(dict_data)
print(type(dict_data))

temp_list = data['temp'].to_list()
print(temp_list)
print(len(temp_list)) 
print("\n")

print(sum(temp_list)/len(temp_list))
print(data['temp'].mean())
print(data['temp'].max())  

print(data.condition)
# print(data['condition'])

print(data[data.day == "Monday"])
print(data[data.temp == data.temp.max()])

monday = data[data.day == "Monday"]
print(monday.condition)
temp_in_f = monday.temp *9/5 + 32
print(temp_in_f)

data_dict = {
    "students": ["Amy", "James", "Angela"],
    "scores": [76, 56, 65]
} 
data = pd.DataFrame(data_dict)
print(data)
data.to_csv("new_data.csv")
# Out:
# {'day': {0: 'Monday', 1: 'Tuesday', 2: 'Wednesday', 3: 'Thursday', 4: 'Friday', 5: 'Saturday', 6: 'Sunday'}, 'temp': {0: 12, 1: 14, 2: 15, 3: 14, 4: 21, 5: 22, 6: 24}, 'condition': {0: 'Sunny', 1: 'Rain', 2: 'Rain', 3: 'Cloudy', 4: 'Sunny', 5: 'Sunny', 6: 'Sunny'}}
# <class 'dict'>
# [12, 14, 15, 14, 21, 22, 24]
# 7
#
#
# 17.428571428571427
# 17.428571428571427
# 24
# 0     Sunny
# 1      Rain
# 2      Rain
# 3    Cloudy
# 4     Sunny
# 5     Sunny
# 6     Sunny
# Name: condition, dtype: object
#       day  temp condition
# 0  Monday    12     Sunny
#       day  temp condition
# 6  Sunday    24     Sunny
# 0    Sunny
# Name: condition, dtype: object
# 0    53.6
# Name: temp, dtype: float64
#   students  scores
# 0      Amy      76
# 1    James      56
# 2   Angela      65

# %% [markdown]
# https://data.cityofnewyork.us/Environment/2018-Central-Park-Squirrel-Census-Squirrel-Data/vfnx-vebw/about_data
# Squirrel Census

# %%
import pandas as pd
data = pd.read_csv("2018_Central_Park_Squirrel_Census_-_Squirrel_Data.csv")
gray_squirrels_count = len(data[data["Primary Fur Color"] == "Gray"])
red_squirrels_count = len(data[data["Primary Fur Color"] == "Cinnamon"])
black_squirrels_count = len(data[data["Primary Fur Color"] == "Black"])
print(gray_squirrels_count)
print(red_squirrels_count)
print(black_squirrels_count)
data_dict = {  
    "Fur Color": ["Gray", "Cinnamon", "Black"],
    "Count": [gray_squirrels_count, red_squirrels_count, black_squirrels_count]
}
data = pd.DataFrame(data_dict)
data.to_csv("squirrel_count.csv")
# Out:
# 2473
# 392
# 103

# %% [markdown]
# List Comprehension

# %%
# new_list = new_item for item in list]
numbers = [1, 2, 3, 4, 5]
new_list = [n+1 for n in numbers]
print(new_list)

name = "Alexandra"
new_list = [i.upper() for i in name]
print(new_list)

new_list = [n*2 for n in range(1,5)]
print(new_list)
# Out:
# [2, 3, 4, 5, 6]
# ['A', 'L', 'E', 'X', 'A', 'N', 'D', 'R', 'A']
# [2, 4, 6, 8]

# %% [markdown]
# Conditional List Comprehension

# %%
#new_list = [new_item for item in list if test]

names = ["Alex", "Beth", "Caroline", "Dave", "Eleanor", "Freddie"]
short_names = [name for name in names if len(name) <5]
print(short_names)
long_names = [name.upper() for name in names if len(name) >4]
print(long_names)
# Out:
# ['Alex', 'Beth', 'Dave']
# ['CAROLINE', 'ELEANOR', 'FREDDIE']

# %%
data1 = ["1", "2", "3", "4", "5"]
data2 = ["3", "4", "5", "6", "7"]

result = [int(num) for num in data1 if num in data2]

print(result)
# Out:
# [3, 4, 5]

# %% [markdown]
# Dictionary Comprehension

# %%
#new_dict = {new_key: new_value for (key,value) in dict.items() if test}

names = ["Alex", "Beth", "Caroline", "Dave", "Eleanor", "Freddie"]
import random
marks = {name: random.randint(0,100) for name in names}
print(marks)

passed_students = {name: score for (name,score) in marks.items() if score >=60}
print(passed_students)
# Out:
# {'Alex': 0, 'Beth': 50, 'Caroline': 85, 'Dave': 99, 'Eleanor': 13, 'Freddie': 30}
# {'Caroline': 85, 'Dave': 99}

# %%
sentence = "What is the Airspeed Velocity of an Unladen Swallow?"
words = sentence.split()
result = {word: len(word) for word in words}
print(result)
# Out:
# {'What': 4, 'is': 2, 'the': 3, 'Airspeed': 8, 'Velocity': 8, 'of': 2, 'an': 2, 'Unladen': 7, 'Swallow?': 8}

# %%
weather_c = {"Monday": 12, "Tuesday": 14, "Wednesday": 15, "Thursday": 14, "Friday": 21, "Saturday": 22, "Sunday": 24}

weather_f = {day : tempc*9/5+32 for (day,tempc) in weather_c.items()}

print(weather_f)
# Out:
# {'Monday': 53.6, 'Tuesday': 57.2, 'Wednesday': 59.0, 'Thursday': 57.2, 'Friday': 69.8, 'Saturday': 71.6, 'Sunday': 75.2}
